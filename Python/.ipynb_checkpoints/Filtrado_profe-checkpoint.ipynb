# %% [markdown]
# # Filtrar la data para Mantenimiento predictivo (Predictive maintenance) = Time To Event Model
#
#
# * Filtraremos por discos duros que fallaron en el año dado (tanto por conveniencia como por tamaño del archivo).
#
# * Más adelante usaremos estos datos para crear un modelo de regresión: tiempo de falla.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\rolft\Documents\UAI\UAI_2020\AP_git\me_code\Prueba_2\data\harddrive.csv')
print(df.shape)
df.head()
# Out:
# (3179295, 95)
#          date    serial_number                    model  capacity_bytes  \
# 0  2016-01-01   MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   1.482490e-311
# 1  2016-01-01         Z305B2QN              ST4000DM000   1.976651e-311
# 2  2016-01-01   MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   1.482490e-311
# 3  2016-01-01   MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   1.482490e-311
# 4  2016-01-01  WD-WMC4N2899475             WDC WD30EFRX   1.482490e-311
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 100            0               135.0        108.0
# 1        0                 113     54551400                 NaN          NaN
# 2        0                 100            0               136.0        104.0
# 3        0                 100            0               136.0        104.0
# 4        0                 200            0                 NaN          NaN
#
#    smart_3_normalized  ...  smart_250_normalized  smart_250_raw  \
# 0                 143  ...                   NaN            NaN
# 1                  96  ...                   NaN            NaN
# 2                 124  ...                   NaN            NaN
# 3                 137  ...                   NaN            NaN
# 4                 175  ...                   NaN            NaN
#
#    smart_251_normalized  smart_251_raw  smart_252_normalized  smart_252_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_254_normalized  smart_254_raw  smart_255_normalized  smart_255_raw
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
# [5 rows x 95 columns]

# %%
df.describe(include='all')
# Out:
#               date   serial_number        model  capacity_bytes       failure  \
# count      3179295         3179295      3179295    3.179295e+06  3.179295e+06
# unique          50           65993           69             NaN           NaN
# top     2016-04-01  JK11A8B9HZTN8R  ST4000DM000             NaN           NaN
# freq        125904              52      1681473             NaN           NaN
# mean           NaN             NaN          NaN   1.849552e-311  6.762506e-05
# std            NaN             NaN          NaN    0.000000e+00  8.223169e-03
# min            NaN             NaN          NaN   3.953828e-313  0.000000e+00
# 25%            NaN             NaN          NaN   1.976651e-311  0.000000e+00
# 50%            NaN             NaN          NaN   1.976651e-311  0.000000e+00
# 75%            NaN             NaN          NaN   1.976651e-311  0.000000e+00
# max            NaN             NaN          NaN   3.953298e-311  1.000000e+00
#
#         smart_1_normalized   smart_1_raw  smart_2_normalized   smart_2_raw  \
# count         3.179295e+06  3.179295e+06        1.259118e+06  1.259118e+06
# unique                 NaN           NaN                 NaN           NaN
# top                    NaN           NaN                 NaN           NaN
# freq                   NaN           NaN                 NaN           NaN
# mean          1.121816e+02  6.856751e+07        1.287652e+02  7.491735e+01
# std           1.871325e+01  8.002785e+07        2.488450e+01  4.557482e+01
# min           3.300000e+01  0.000000e+00        1.000000e+02  0.000000e+00
# 25%           1.000000e+02  0.000000e+00        1.310000e+02  0.000000e+00
# 50%           1.120000e+02  2.984580e+07        1.330000e+02  1.000000e+02
# 75%           1.170000e+02  1.343214e+08        1.340000e+02  1.040000e+02
# max           2.000000e+02  1.916485e+09        2.520000e+02  1.960000e+02
#
#         smart_3_normalized  ...  smart_250_normalized  smart_250_raw  \
# count         3.179295e+06  ...                2835.0   2.835000e+03
# unique                 NaN  ...                   NaN            NaN
# top                    NaN  ...                   NaN            NaN
# freq                   NaN  ...                   NaN            NaN
# mean          1.052967e+02  ...                   1.0   1.020068e+08
# std           1.870145e+01  ...                   0.0   7.223558e+07
# min           7.000000e+01  ...                   1.0   2.452300e+04
# 25%           9.400000e+01  ...                   1.0   1.462176e+07
# 50%           9.800000e+01  ...                   1.0   1.412617e+08
# 75%           1.140000e+02  ...                   1.0   1.667429e+08
# max           2.530000e+02  ...                   1.0   1.992453e+08
#
#         smart_251_normalized  smart_251_raw  smart_252_normalized  \
# count            2835.000000   2.835000e+03           2835.000000
# unique                   NaN            NaN                   NaN
# top                      NaN            NaN                   NaN
# freq                     NaN            NaN                   NaN
# mean                6.412698   1.948479e+08             19.822222
# std                22.510855   1.462246e+08             38.854298
# min                 1.000000   6.600000e+01              1.000000
# 25%                 1.000000   1.722997e+07              1.000000
# 50%                 1.000000   2.741461e+08              1.000000
# 75%                 1.000000   3.278856e+08              1.000000
# max               100.000000   3.862757e+08            100.000000
#
#         smart_252_raw  smart_254_normalized  smart_254_raw  \
# count    2.835000e+03           7935.000000         7935.0
# unique            NaN                   NaN            NaN
# top               NaN                   NaN            NaN
# freq              NaN                   NaN            NaN
# mean     8.940533e+07            116.131065            0.0
# std      6.703960e+07             36.784042            0.0
# min      0.000000e+00            100.000000            0.0
# 25%      7.881220e+06            100.000000            0.0
# 50%      1.254753e+08            100.000000            0.0
# 75%      1.500801e+08            100.000000            0.0
# max      1.782887e+08            200.000000            0.0
#
#         smart_255_normalized  smart_255_raw
# count                    0.0            0.0
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                     NaN            NaN
# std                      NaN            NaN
# min                      NaN            NaN
# 25%                      NaN            NaN
# 50%                      NaN            NaN
# 75%                      NaN            NaN
# max                      NaN            NaN
#
# [11 rows x 95 columns]

# %%
# drop constant columns
df = df.loc[:, ~df.isnull().all()]
print(df.shape)
# Out:
# (3179295, 91)

# %%
# number of hdd
print("number of hdd:", df['serial_number'].value_counts().shape) 

# number of different types of harddrives
print("number of different harddrives", df['model'].value_counts().shape)
# Out:
# number of hdd: (65993,)
# number of different harddrives (69,)

# %% [markdown]
# # Conservaremos solo los discos duros (HDDs) que fallaron
#
# * Idealmente, usaríamos varios años de datos para más modelos y rango. Hay un gran sesgo aquí cuando no incluimos discos duros que no fallaron.
#
#     * También perdemos la capacidad de identificar discos duros (HDDs) verdaderamente "saludables".

# %%
#.loc indexa a traves de la selección tipo array
failed_hdds = df.loc[df.failure==1]["serial_number"]
len(failed_hdds)
failed_hdds.describe()
# Out:
# count          214
# unique         205
# top       W3006E5B
# freq             2
# Name: serial_number, dtype: object

# %% [markdown]
# Se encontró un item que fallo dos veces coon el mismo ID, se indigará este item para ver si se utilizó su id de nuevo.

# %%
#& df.serial_number=='WD-WCC4MKDL77ZK'
caso_rraro=df.loc[df.failure==1 ]#["serial_number"]
caso_rraro=caso_rraro.loc[caso_rraro.serial_number=='WD-WCC4MKDL77ZK']
caso_rraro#.describe()
# Out:
#              date    serial_number         model  capacity_bytes  failure  \
# 30285  2016-01-01  WD-WCC4MKDL77ZK  WDC WD20EFRX   9.883284e-312        1
# 87830  2016-01-01  WD-WCC4MKDL77ZK  WDC WD20EFRX   9.883284e-312        1
#
#        smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 30285                 200            0                 NaN          NaN
# 87830                 200            0                 NaN          NaN
#
#        smart_3_normalized  ...  smart_242_normalized  smart_242_raw  \
# 30285                 100  ...                   NaN            0.0
# 87830                 100  ...                   NaN            0.0
#
#        smart_250_normalized  smart_250_raw  smart_251_normalized  \
# 30285                   NaN            NaN                   NaN
# 87830                   NaN            NaN                   NaN
#
#        smart_251_raw  smart_252_normalized  smart_252_raw  \
# 30285            NaN                   NaN            NaN
# 87830            NaN                   NaN            NaN
#
#        smart_254_normalized  smart_254_raw
# 30285                   NaN            NaN
# 87830                   NaN            NaN
#
# [2 rows x 91 columns]

# %% [markdown]
# Se aprecia que este Item fallo dos veces el mismo dia, es completamente un dato duplicado, por lo cual se procede a eliminar.

# %%
item_A=df.loc[df.serial_number=='WD-WCC4MKDL77ZK']
item_A
# Out:
#              date    serial_number         model  capacity_bytes  failure  \
# 30285  2016-01-01  WD-WCC4MKDL77ZK  WDC WD20EFRX   9.883284e-312        1
# 87830  2016-01-01  WD-WCC4MKDL77ZK  WDC WD20EFRX   9.883284e-312        1
#
#        smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 30285                 200            0                 NaN          NaN
# 87830                 200            0                 NaN          NaN
#
#        smart_3_normalized  ...  smart_250_normalized  smart_250_raw  \
# 30285                 100  ...                   NaN            NaN
# 87830                 100  ...                   NaN            NaN
#
#        smart_251_normalized  smart_251_raw  smart_252_normalized  \
# 30285                   NaN            NaN                   NaN
# 87830                   NaN            NaN                   NaN
#
#        smart_252_raw  smart_254_normalized  smart_254_raw  \
# 30285            NaN                   NaN            NaN
# 87830            NaN                   NaN            NaN
#
#        smart_255_normalized  smart_255_raw
# 30285                   NaN            NaN
# 87830                   NaN            NaN
#
# [2 rows x 95 columns]

# %%
# eliminamos la data que esta repetida
df=df.drop([87830],axis=0)

# %% [markdown]
# No posee historia osea que falló en T=1, en el primer instante que aprece en la data

# %%
df = df.loc[df["serial_number"].isin(failed_hdds)]
df.shape
# Out:
# (5489, 91)

# %%
df.to_csv("data_fail.csv", index = False, sep=',', encoding='utf-8')

# %% [markdown]
# # Trabajar con data_fail

# %%
df = pd.read_csv(r'data\data_fail.csv')
print(df.shape)
df.head()

# %%
#Crear una columna con el dia en que muere el articulo
df["end_date"] = df.groupby("serial_number")["date"].transform("max")
# Out:
# C:\Users\rolft\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
# 3072374          NaN                  97  ...  1.112559e-313
# 3074838          0.0                 118  ...   0.000000e+00
# 3079138          NaN                  97  ...  7.351195e-315
# 3084009          NaN                  98  ...  2.008446e-313
# 3084227          NaN                  98  ...  3.733211e-315
# 3100634          NaN                  98  ...  7.902839e-314
# 3105860          NaN                  91  ...  5.084032e-313
# 3136939          NaN                  97  ...  1.112712e-313
# 3139403          0.0                 118  ...   0.000000e+00
#
#          smart_250_normalized  smart_250_raw  smart_251_normalized  \
# 376                       NaN            NaN                   NaN
# 1657                      NaN            NaN                   NaN
# 1895                      NaN            NaN                   NaN
# 2900                      NaN            NaN                   NaN
# 3204                      NaN            NaN                   NaN
# 3615                      NaN            NaN                   NaN
# 3721                      NaN            NaN                   NaN
# 3784                      NaN            NaN                   NaN
# 3809                      NaN            NaN                   NaN
# 3909                      1.0     13579666.0                   1.0
# 3959                      NaN            NaN                   NaN
# 4064                      NaN            NaN                   NaN
# 4220                      NaN            NaN                   NaN
# 5240                      NaN            NaN                   NaN
# 5714                      NaN            NaN                   NaN
# 5824                      NaN            NaN                   NaN
# 5830                      NaN            NaN                   NaN
# 6029                      NaN            NaN                   NaN
# 6393                      NaN            NaN                   NaN
# 6520                      NaN            NaN                   NaN
# 7677                      NaN            NaN                   NaN
# 7912                      NaN            NaN                   NaN
# 8007                      NaN            NaN                   NaN
# 8289                      NaN            NaN                   NaN
# 8385                      NaN            NaN                   NaN
# 9036                      NaN            NaN                   NaN
# 9477                      NaN            NaN                   NaN
# 9874                      NaN            NaN                   NaN
# 10711                     NaN            NaN                   NaN
# 11131                     NaN            NaN                   NaN
# ...                       ...            ...                   ...
# 3005981                   1.0     28481099.0                   1.0
# 3007719                   NaN            NaN                   NaN
# 3007758                   NaN            NaN                   NaN
# 3010185                   NaN            NaN                   NaN
# 3010423                   NaN            NaN                   NaN
# 3014495                   NaN            NaN                   NaN
# 3019379                   NaN            NaN                   NaN
# 3019599                   1.0    183869206.0                   1.0
# 3021607                   NaN            NaN                   NaN
# 3036033                   NaN            NaN                   NaN
# 3037837                   NaN            NaN                   NaN
# 3041273                   NaN            NaN                   NaN
# 3043089                   NaN            NaN                   NaN
# 3063668                   NaN            NaN                   NaN
# 3064072                   1.0    112676214.0                   1.0
# 3064433                   1.0     11449236.0                   1.0
# 3065905                   NaN            NaN                   NaN
# 3066002                   1.0    181975578.0                   1.0
# 3067544                   1.0    169686044.0                   1.0
# 3067625                   NaN            NaN                   NaN
# 3070640                   1.0     28659559.0                   1.0
# 3072374                   NaN            NaN                   NaN
# 3074838                   NaN            NaN                   NaN
# 3079138                   NaN            NaN                   NaN
# 3084009                   NaN            NaN                   NaN
# 3084227                   1.0    184044804.0                   1.0
# 3100634                   NaN            NaN                   NaN
# 3105860                   NaN            NaN                   NaN
# 3136939                   NaN            NaN                   NaN
# 3139403                   NaN            NaN                   NaN
#
#          smart_251_raw  smart_252_normalized  smart_252_raw  \
# 376                NaN                   NaN            NaN
# 1657               NaN                   NaN            NaN
# 1895               NaN                   NaN            NaN
# 2900               NaN                   NaN            NaN
# 3204               NaN                   NaN            NaN
# 3615               NaN                   NaN            NaN
# 3721               NaN                   NaN            NaN
# 3784               NaN                   NaN            NaN
# 3809               NaN                   NaN            NaN
# 3909        26548746.0                   1.0     12207968.0
# 3959               NaN                   NaN            NaN
# 4064               NaN                   NaN            NaN
# 4220               NaN                   NaN            NaN
# 5240               NaN                   NaN            NaN
# 5714               NaN                   NaN            NaN
# 5824               NaN                   NaN            NaN
# 5830               NaN                   NaN            NaN
# 6029               NaN                   NaN            NaN
# 6393               NaN                   NaN            NaN
# 6520               NaN                   NaN            NaN
# 7677               NaN                   NaN            NaN
# 7912               NaN                   NaN            NaN
# 8007               NaN                   NaN            NaN
# 8289               NaN                   NaN            NaN
# 8385               NaN                   NaN            NaN
# 9036               NaN                   NaN            NaN
# 9477               NaN                   NaN            NaN
# 9874               NaN                   NaN            NaN
# 10711              NaN                   NaN            NaN
# 11131              NaN                   NaN            NaN
# ...                ...                   ...            ...
# 3005981     56398869.0                   1.0     25661401.0
# 3007719            NaN                   NaN            NaN
# 3007758            NaN                   NaN            NaN
# 3010185            NaN                   NaN            NaN
# 3010423            NaN                   NaN            NaN
# 3014495            NaN                   NaN            NaN
# 3019379            NaN                   NaN            NaN
# 3019599    358327380.0                   1.0    164103254.0
# 3021607            NaN                   NaN            NaN
# 3036033            NaN                   NaN            NaN
# 3037837            NaN                   NaN            NaN
# 3041273            NaN                   NaN            NaN
# 3043089            NaN                   NaN            NaN
# 3063668            NaN                   NaN            NaN
# 3064072    210661075.0                   1.0     99013941.0
# 3064433     22924469.0                   1.0     10324409.0
# 3065905            NaN                   NaN            NaN
# 3066002    356526577.0                   1.0    162983113.0
# 3067544    331807798.0                   1.0    151444174.0
# 3067625            NaN                   NaN            NaN
# 3070640     56756206.0                   1.0     25825009.0
# 3072374            NaN                   NaN            NaN
# 3074838            NaN                   NaN            NaN
# 3079138            NaN                   NaN            NaN
# 3084009            NaN                   NaN            NaN
# 3084227    358677046.0                   1.0    164262565.0
# 3100634            NaN                   NaN            NaN
# 3105860            NaN                   NaN            NaN
# 3136939            NaN                   NaN            NaN
# 3139403            NaN                   NaN            NaN
#
#          smart_254_normalized  smart_254_raw    end_date
# 376                       NaN            NaN  2016-01-17
# 1657                      NaN            NaN  2016-04-09
# 1895                      NaN            NaN  2016-04-18
# 2900                      NaN            NaN  2016-04-09
# 3204                      NaN            NaN  2016-01-10
# 3615                      NaN            NaN  2016-04-05
# 3721                      NaN            NaN  2016-04-05
# 3784                      NaN            NaN  2016-01-11
# 3809                      NaN            NaN  2016-01-05
# 3909                    100.0            0.0  2016-01-21
# 3959                      NaN            NaN  2016-04-06
# 4064                      NaN            NaN  2016-04-01
# 4220                      NaN            NaN  2016-01-13
# 5240                      NaN            NaN  2016-01-03
# 5714                      NaN            NaN  2016-01-06
# 5824                      NaN            NaN  2016-04-25
# 5830                      NaN            NaN  2016-04-13
# 6029                      NaN            NaN  2016-04-18
# 6393                      NaN            NaN  2016-01-19
# 6520                      NaN            NaN  2016-04-11
# 7677                      NaN            NaN  2016-04-01
# 7912                      NaN            NaN  2016-04-11
# 8007                      NaN            NaN  2016-01-06
# 8289                      NaN            NaN  2016-04-06
# 8385                      NaN            NaN  2016-01-02
# 9036                      NaN            NaN  2016-01-05
# 9477                      NaN            NaN  2016-04-15
# 9874                      NaN            NaN  2016-04-06
# 10711                     NaN            NaN  2016-04-15
# 11131                     NaN            NaN  2016-04-04
# ...                       ...            ...         ...
# 3005981                 100.0            0.0  2016-04-28
# 3007719                   NaN            NaN  2016-04-29
# 3007758                   NaN            NaN  2016-04-27
# 3010185                   NaN            NaN  2016-04-29
# 3010423                   NaN            NaN  2016-04-27
# 3014495                   NaN            NaN  2016-04-28
# 3019379                   NaN            NaN  2016-04-28
# 3019599                 100.0            0.0  2016-04-28
# 3021607                   NaN            NaN  2016-04-27
# 3036033                   NaN            NaN  2016-04-28
# 3037837                   NaN            NaN  2016-04-27
# 3041273                   NaN            NaN  2016-04-28
# 3043089                   NaN            NaN  2016-04-27
# 3063668                   NaN            NaN  2016-04-28
# 3064072                 100.0            0.0  2016-04-28
# 3064433                 100.0            0.0  2016-04-28
# 3065905                   NaN            NaN  2016-04-28
# 3066002                 100.0            0.0  2016-04-28
# 3067544                 100.0            0.0  2016-04-28
# 3067625                   NaN            NaN  2016-04-28
# 3070640                 100.0            0.0  2016-04-28
# 3072374                   NaN            NaN  2016-04-29
# 3074838                   NaN            NaN  2016-04-29
# 3079138                   NaN            NaN  2016-04-28
# 3084009                   NaN            NaN  2016-04-28
# 3084227                 100.0            0.0  2016-04-28
# 3100634                   NaN            NaN  2016-04-28
# 3105860                   NaN            NaN  2016-04-28
# 3136939                   NaN            NaN  2016-04-29
# 3139403                   NaN            NaN  2016-04-29
#
# [5490 rows x 92 columns]

# %%
df["end_date"] = pd.to_datetime(df["end_date"])
df["date"] = pd.to_datetime(df["date"])

# %%
df["date_diff"] = df["end_date"] - df["date"]
df["date_diff"].describe()
# Out:
# count                       5490
# mean     49 days 09:18:25.573770
# std      44 days 09:17:21.395230
# min              0 days 00:00:00
# 25%              7 days 00:00:00
# 50%             21 days 00:00:00
# 75%             95 days 00:00:00
# max            119 days 00:00:00
# Name: date_diff, dtype: object

# %%
df["smart_9_raw"].describe()
# Out:
# count     5490.000000
# mean     19560.998725
# std      12483.140262
# min         14.000000
# 25%       9535.750000
# 50%      19234.500000
# 75%      25783.000000
# max      67744.000000
# Name: smart_9_raw, dtype: float64

# %% [markdown]
# * Parece que las fallas tienen una distribución extraña. tal vez estén agrupados alrededor del inicio / final de un año / trimestre.
#
# * NOTE que dejar la fecha en la fecha dará lugar a una fuga en nuestro modelo si no tenemos cuidado (más adelante en el [mismo] año = mayor probabilidad de falla!

# %% [markdown]
# # replace string/object with number
# df["date_diff"] = df["date_diff"].dt.days
# df.drop(["end_date","failure"],axis=1,inplace=True)
# print(df.shape)

# %% [markdown]
# # replace string/object with number
# df["date_diff"] = df["date_diff"].dt.days
# df.drop(["end_date","failure"],axis=1,inplace=True)
# print(df.shape)

# %%
df.to_dense().to_csv("submission.csv", index = False, sep=',', encoding='utf-8')
